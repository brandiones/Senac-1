# %%
print("Olá Ricardo, está a procura de emprego?")
# Out:
# Olá Ricardo, está a procura de emprego?

# %% [markdown]
# Comando print("mostra o que foi escrito")
#
# Conhecendo Variáveis

# %%
nome = "Walison"

# %%
idade= 19

# %%
print("Olá,", nome)
# Out:
# Olá, Walison

# %%
pessoa= "Brandão"
idade= 37
altura= 1.80
dev= True
