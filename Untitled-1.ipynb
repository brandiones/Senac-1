# %%
"""comentando código
comentando código
comentando código
comentando código
comentando código
comentando código
comentando código
comentando código
"""
# Out:
# 'comentando código\ncomentando código\ncomentando código\ncomentando código\ncomentando código\ncomentando código\ncomentando código\ncomentando código\n'

# %%
"""Declaração de soma dos valores"""

idade1 = 20
idade2 = 35

idade1 + idade2
# Out:
# 55

# %%
"""Declaração de divisão dos valores"""

idade1 - idade2
# Out:
# -15

# %%
"""Declaração da multiplicação dos valores"""

idade1 * idade2
# Out:
# 700

# %%
"""Declaração da divisão dos valores"""

idade2 / idade1
# Out:
# 1.75

# %%
"""Declaração das somas na tela"""

somaIdades=idade1+idade2
print(somaIdades)
# Out:
# 55

# %%
calculo1 = 2 *(idade1 + idade2)

# %%
calculo2 = 2 *(idade1 + 3 * idade2) / 4

# %%
calculo3 = (2 * idade1 + 3 * idade2) / 4

# %%
print(calculo1)
print(calculo2)
print(calculo3)
# Out:
# 110
# 62.5
# 36.25

# %%
print(calculo1 , calculo2 , calculo3)
# Out:
# 110 62.5 36.25

# %%
idade1 ** 2
# Out:
# 400

# %%
15 ** 2
# Out:
# 225

# %%
idade2 // idade1
# Out:
# 1

# %%
idade1 / idade2
# Out:
# 0.5714285714285714

# %%
idade2 % idade1
# Out:
# 15

# %%
"""Declaração do PEMDS"""

#Parêtesis
#Expoente
#Multiplicação
#Divisão
#Subtração
# Out:
# 'Declaração do PEMDS'

# %%
nome = "Walison"
sobrenome = "Brandão"
print(nome + sobrenome)
# Out:
# WalisonBrandão

# %%
print(nome + '' + sobrenome)
# Out:
# WalisonBrandão

# %%
print('Olá,', nome, sobrenome, 'você tem' , idade1 + 15, 'anos.')
# Out:
# Olá, Walison Brandão você tem 35 anos.

# %%
print('\n' , 'Olá,', nome, sobrenome,  '\n', 'você tem', idade1 + 15, 'anos.')
# Out:
#  Olá, Walison Brandão
#  você tem 35 anos.

# %%
idadeA = input("Digite sua idade: ")

# %%
print(idadeA)
# Out:
# 20

# %%
type(idadeA)
# Out:
# str

# %%
idadeB = int(input("Digite sua idade:"))

# %%
type(idadeB)
# Out:
# int

# %%
print(idadeB)
# Out:
# 19

# %%
num1 = 19
num1 -= 8
print(num1)
# Out:
# 11

# %%
num2 = 8
num2 +=11
print(num2)
# Out:
# 19
